# %% [markdown]
# # get menu from the locu api

# %%
import json, os
import pickle
import requests
import nltk
import pickle, re
import string 
import unicodedata

from nltk import word_tokenize, sent_tokenize

# %%
# read from the previously generated menu file 
def readBuzs():
    if os.path.isfile(BUZ_PICKLE_FILE):
        buzs = pickle.load(open(BUZ_PICKLE_FILE, 'rb'))
    else:
        buzs = {}
    if os.path.isfile(BUZ_MENU_PICKLE_FILE):
        buzs_with_menu = pickle.load(open(BUZ_MENU_PICKLE_FILE, 'rb'))
    else:
        buzs_with_menu = {}
    return (buzs, buzs_with_menu)

# %%
BUZ_PICKLE_FILE = 'buzs.pickle'
BUZ_MENU_PICKLE_FILE = 'buzs_with_menu.pickle'

buzs, buzs_with_menu = readBuzs()
count = 0
with open("business.json") as f:
    for line in f:
        buz = json.loads(line)
        count += 1
        # Skip if this venue is not a restaurant 
        if "Restaurants" not in buz["categories"]:
            continue
        # Skip if this restaurant has been read 
        if buz["business_id"] in buzs:
            continue
        # Dictionary that map "business_id" to corresponding restaurant
        buzs[buz["business_id"]] = buz
        url = "https://api.locu.com/v2/venue/search"
        params = {
            "fields" : [ "name", "menus" ],
            "venue_queries" : [
                {
                    "name" : buz["name"],
                    "location" : {"region" : buz["state"], "locality" : buz["city"], "postal_code" : buz["postal_code"]},
                    "menus" : { "$present" : True },
                }
            ],
            "api_key" : "af31648d127d362397e9ad94c8df49665111f52c",
        }
        # Equals to data=json.dumps(params)
        response = requests.post(url, json=params)
        if response.status_code != 200:
            print('Status code error:', response.status_code)
            #print(response.text)
            del buzs[buz['business_id']]
            break
        content = json.loads(response.content)
        if len(content["venues"]) == 0:
            continue
        print("New buz_with_menu count:", count)
        buz['venues'] = content['venues']
        buzs_with_menu[buz['business_id']] = buz


pickle.dump(buzs, open('buzs.pickle', 'wb'))
pickle.dump(buzs_with_menu, open('buzs_with_menu.pickle', 'wb'))
print('Final result')
print('Num of buzs:', len(buzs))
print('Num of buzs with menu:', len(buzs_with_menu))
# Out:
# Status code error: 429
# Final result
# Num of buzs: 0
# Num of buzs with menu: 3442

# %% [markdown]
# # del venue in buzs, append menu

# %%
'''
Extract menu info from raw data.
Append menu into the buz data structure
Delete unrelated information from buz
'''

buzs = pickle.load(open('buzs_with_menu.pickle', 'rb'))
buzs_simple = {}

count = 0
for buz_id, buz in buzs.items():
    count += 1
    #print(count, buz_id)
    if ('venues' not in buz) or (len(buz['venues']) == 0):
        print('No venues for {}'.format(buz_id))
    venue = buz['venues'][0]
    if ('menus' not in venue) or (len(venue['menus']) == 0):
        print('No menus for {}'.format(buz_id))
    menus = venue['menus']
    food = []
    for menu in menus:
        for section in menu['sections']:
            for subsection in section['subsections']:
                for content in subsection['contents']:
                    food.append(content)
    del buz['venues']
    buz['menu'] = food
    buzs_simple[buz_id] = buz
pickle.dump(buzs_simple, open('buzs_simple.pickle', 'wb'))

# %% [markdown]
# # tokenize review

# %%
'''
Tokenize business reviews. Each review becomes a list of tokens. Remove the sentences that have more than
50 tokens, remove token string that has more than 20 characters
Input file: review.json
            buzs_simple.pickle
Output file: tokenized_reviews.pickle
'''

REVIEW_FILE_NAME = 'review.json'
BUZ_FILE_NAME = 'buzs_simple.pickle'

buzs = pickle.load(open(BUZ_FILE_NAME, 'rb'))
buz_ids = buzs.keys()

buz_reviews = {buz_id: [] for buz_id in buz_ids}

# tokenize reviews
total_count = 0
relevant_count = 0
with open(REVIEW_FILE_NAME) as f:
    for line in f:
        total_count += 1
        review = json.loads(line)
        buz_id = review['business_id']
        if buz_id in buz_ids:
            relevant_count += 1
            # Remove punctuation and Foreign characters
            review_text = review['text']
            review_text = unicodedata.normalize('NFD', review_text).encode('ascii', 'ignore').decode('utf-8')
            sent_tokens = sent_tokenize(review_text)
            sents = []
            for sent in sent_tokens:
                sent = re.sub(r'(w/)', 'with', sent)
                sent = re.sub(r'[\d]|[^\w\s]', '', sent)
                tokens = word_tokenize(sent)
                tokens = [token.lower() for token in tokens if len(token) < 20]
                if len(tokens) > 50:
                    continue
                sents.append(tokens)
            review['text'] = sents
            buz_reviews[buz_id].append(review)
        if total_count % 10000 == 0:
            print('Total review processed:', total_count)
            print('Relevant review:', relevant_count)

pickle.dump(buz_reviews, open('tokenized_reviews.pickle', 'wb'))
# Out:
# Total review processed: 10000
# Relevant review: 645
# Total review processed: 20000
# Relevant review: 1059
# Total review processed: 30000
# Relevant review: 1786
# Total review processed: 40000
# Relevant review: 1974
# Total review processed: 50000
# Relevant review: 2251
# Total review processed: 60000
# Relevant review: 3204
# Total review processed: 70000
# Relevant review: 3702
# Total review processed: 80000
# Relevant review: 4153
# Total review processed: 90000
# Relevant review: 4431
# Total review processed: 100000
# Relevant review: 5262
# Total review processed: 110000
# Relevant review: 6013
# Total review processed: 120000
# Relevant review: 6348
# Total review processed: 130000
# Relevant review: 6779
# Total review processed: 140000
# Relevant review: 7129
# Total review processed: 150000
# Relevant review: 7828
# Total review processed: 160000
# Relevant review: 8668
# Total review processed: 170000
# Relevant review: 9139
# Total review processed: 180000
# Relevant review: 9611
# Total review processed: 190000
# Relevant review: 10259
# Total review processed: 200000
# Relevant review: 10343
# Total review processed: 210000
# Relevant review: 11293
# Total review processed: 220000
# Relevant review: 12017
# Total review processed: 230000
# Relevant review: 12501
# Total review processed: 240000
# Relevant review: 13521
# Total review processed: 250000
# Relevant review: 14671
# Total review processed: 260000
# Relevant review: 15142
# Total review processed: 270000
# Relevant review: 15856
# Total review processed: 280000
# Relevant review: 16886
# Total review processed: 290000
# Relevant review: 18302
# Total review processed: 300000
# Relevant review: 19117
# Total review processed: 310000
# Relevant review: 19819
# Total review processed: 320000
# Relevant review: 20582
# Total review processed: 330000
# Relevant review: 21100
# Total review processed: 340000
# Relevant review: 21918
# Total review processed: 350000
# Relevant review: 22813
# Total review processed: 360000
# Relevant review: 23284
# Total review processed: 370000
# Relevant review: 23935
# Total review processed: 380000
# Relevant review: 24518
# Total review processed: 390000
# Relevant review: 24907
# Total review processed: 400000
# Relevant review: 26043
# Total review processed: 410000
# Relevant review: 27190
# Total review processed: 420000
# Relevant review: 27884
# Total review processed: 430000
# Relevant review: 29305
# Total review processed: 440000
# Total review processed: 4510000
# Relevant review: 283122
# Total review processed: 4520000
# Relevant review: 283181
# Total review processed: 4530000
# Relevant review: 284540
# Total review processed: 4540000
# Relevant review: 285325
# Total review processed: 4550000
# Relevant review: 285818
# Total review processed: 4560000
# Relevant review: 286978
# Total review processed: 4570000
# Relevant review: 287658
# Total review processed: 4580000
# Relevant review: 288484
# Total review processed: 4590000
# Relevant review: 288756
# Total review processed: 4600000
# Relevant review: 290702
# Total review processed: 4610000
# Relevant review: 291053
# Total review processed: 4620000
# Relevant review: 291703
# Total review processed: 4630000
# Relevant review: 292072
# Total review processed: 4640000
# Relevant review: 292730
# Total review processed: 4650000
# Relevant review: 293191
# Total review processed: 4660000
# Relevant review: 293789
# Total review processed: 4670000
# Relevant review: 295835
# Total review processed: 4680000
# Relevant review: 297714
# Total review processed: 4690000
# Relevant review: 297805
# Total review processed: 4700000
# Relevant review: 298302
# Total review processed: 4710000
# Relevant review: 298972
# Total review processed: 4720000
# Relevant review: 301274
# Total review processed: 4730000
# Relevant review: 301773

# %% [markdown]
# # tokenize menu

# %%
'''
Tokenize menu data.
Input file: buzs_simple.pickle
Output file: buzs_tokenized.pickle
contains a dictionary from buz_id -> business.
'''

BUZ_FILE_NAME = 'buzs_simple.pickle'
TOKENIZED_FILE_NAME = 'buzs_tokenized.pickle'

buzs = pickle.load(open(BUZ_FILE_NAME, 'rb'))

count = 0
for buz_id, buz in buzs.items():
    count += 1
    menu = []
    for food in buz['menu']:
        if food['type'] != 'ITEM' or 'name' not in food:
            continue
        food['name'] = re.sub(r'(w/)',"with",food['name'])
        food['name'] = re.sub(r'[\d]|(\([^)]*\))|[^\w\s]', '', food['name'])
        food['name'] = unicodedata.normalize('NFD', food['name']).encode('ascii', 'ignore').decode('utf-8')
        sent_tokens = sent_tokenize(food['name'])
        tokens = word_tokenize(food['name'])
        tokens = [token.lower() for token in tokens]
        food['name'] = tokens
        menu.append(food)
    buz['menu'] = menu
    if count % 50 == 0:
        print('count:', count)
        print(buz['menu'][0])

pickle.dump(buzs, open(TOKENIZED_FILE_NAME, 'wb'))
# Out:
# count: 50
# {'description': 'seared chicken & vegetable dumplings, asian slaw, traditional soy dipping sauce', 'name': ['potstickers'], 'price': '10.25', 'type': 'ITEM'}
# count: 100
# {'type': 'ITEM', 'description': 'Mixed greens, tomato, red onion, cucumber, sweet bell pepper and alfalfa sprouts tossed and garnished with strips of fresh mango and mint served with our delicious homemade ginger dressing', 'name': ['bamboo', 'legend', 'salad'], 'price': '7.99', 'option_groups': [{'text': 'Meat', 'options': [{'name': 'Chicken', 'price': '+2.00'}, {'name': 'Shrimp', 'price': '+3.00'}], 'type': 'OPTION_ADD'}]}
# count: 150
# {'description': 'Prosciutto | basil | marinara', 'name': ['fried', 'stuffed', 'provolone'], 'price': '7.00', 'type': 'ITEM'}
# count: 200
# {'description': 'A third-pound* 100% Angus beef patty with its own special seasoning on a premium bakery style bun, hickory smoked bacon, two slices of melty American cheese and topped off with crisp red onions and Crinkle-cut pickles.', 'name': ['angus', 'bacon', 'and', 'cheese'], 'type': 'ITEM'}
# count: 250
# {'price': '12.00', 'type': 'ITEM', 'name': ['corned', 'beef', 'sandwich'], 'description': 'Brisket cooked\xa0in‐house, swiss, zesty slaw, w/ hand cut fries'}
# count: 300
# {'option_groups': [{'text': 'Size', 'type': 'OPTION_CHOOSE', 'options': [{'price': '3.50', 'name': 'Cup'}, {'price': '6.00', 'name': 'Bowl'}]}, {'text': 'Side', 'type': 'OPTION_ADD', 'options': [{'price': '+2.50', 'name': 'With toasted organic whole wheat pita'}, {'price': '+3.00', 'name': 'With grilled cornbread'}]}], 'type': 'ITEM', 'name': ['soups', 'of', 'the', 'day']}
# count: 350
# {'price': '14.00', 'type': 'ITEM', 'name': ['vegetarian'], 'description': 'Grilled vegetable, (eggplant, zuccini, onions, red & green peppers) served on a bed of mix lettuce, w/ bocconcini & mozzarella cheese, topped w/ secret dressing'}
# count: 400
# {'option_groups': [{'text': 'Price', 'type': 'OPTION_CHOOSE', 'options': [{'price': '18.00', 'name': ''}, {'price': '24.00', 'name': ''}]}], 'type': 'ITEM', 'name': ['aji'], 'description': 'Horse mackerel 4-6 pieces'}
# count: 450
# {'option_groups': [{'text': 'Size', 'type': 'OPTION_CHOOSE', 'options': [{'price': '1.75', 'name': 'Single'}, {'price': '2.50', 'name': 'Double'}]}], 'type': 'ITEM', 'name': ['espresso']}
# count: 500
# {'type': 'ITEM', 'name': ['cherries', 'jubilee', 'ice', 'cream'], 'description': "You're\u200e invited to a Jubilee. Other guests include cherry flavored ice cream, cherry halves, & a hint of rum flavor."}
# count: 550
# {'price': '10.00', 'type': 'ITEM', 'name': ['shrimp', 'cocktail']}
# count: 600
# {'price': '5.00', 'type': 'ITEM', 'name': ['seasonal', 'soup', 'of', 'the', 'day'], 'description': 'With grilled ciabatta'}
# count: 650
# {'type': 'ITEM', 'name': ['steamed', 'mushrooms']}
# count: 700
# {'price': '7.29', 'type': 'ITEM', 'name': ['corned', 'beef']}
# count: 750
# {'price': '6.00', 'type': 'ITEM', 'name': ['beef', 'taco', 'cheese', 'enchilada']}
# count: 800
# {'price': '8.00', 'option_groups': [{'text': 'Cheese', 'type': 'OPTION_CHOOSE', 'options': [{'name': 'American'}, {'name': 'Jalapeno'}]}, {'text': 'Fries', 'type': 'OPTION_CHOOSE', 'options': [{'name': 'Potato salad'}, {'name': 'Chips'}]}], 'type': 'ITEM', 'name': ['lb', 'plain', 'or', 'cheeseburger']}
# count: 850
# {'price': '7.00', 'type': 'ITEM', 'name': ['warm', 'cretan', 'olives'], 'description': 'Olive oil poached / star anise / cinnamon / garlic / fresh herbs'}
# count: 900
# {'price': '8.95', 'type': 'ITEM', 'name': ['quarter', 'chicken', 'meal']}
# count: 950
# {'type': 'ITEM', 'name': ['daves', 'hot', 'n', 'juicy', 'lb', 'single'], 'description': 'A quarter-pound of 100% real North American beef and the freshest premium toppings on buttered, toasted buns - our new gold standard!'}
# count: 1000
# {'price': '14.95', 'type': 'ITEM', 'name': ['adult']}
# count: 1050
# {'price': '6.99', 'type': 'ITEM', 'name': ['bellini'], 'description': 'peach • raspberry • mango • strawberry'}
# count: 1100
# {'type': 'ITEM', 'name': ['starbucks', 'doubleshot', 'energy', 'cinnamon', 'dolce', 'drink'], 'description': 'An invigorating blend of espresso, cinnamon, caramel syrup, b vitamins, guarana & ginseng.'}
# count: 1150
# {'type': 'ITEM', 'name': ['angus', 'bacon', 'cheese'], 'description': 'A third-pound* 100% Angus beef patty w/ its own special seasoning on a premium bakery style bun, hickory smoked bacon, two slices of melty American cheese & topped off w/ crisp red onions & Crinkle-cut pickles.'}
# count: 1200
# {'price': '9.50', 'type': 'ITEM', 'name': ['eggs', 'florentine'], 'description': 'Poached eggs, baby spinach, tomato chutney, Brie on grilled focaccia with hollandaise and field greens'}
# count: 1250
# {'price': '8.00', 'type': 'ITEM', 'name': ['seared', 'scallop', 'duet'], 'description': 'Two seared scallops, one atop sauteed wild mushrooms, the other with crispy applewood bacon, green asparagus and tomato marmalade'}
# count: 1300
# {'type': 'ITEM', 'name': ['loaded', 'omelet', 'biscuit'], 'description': 'A loaded omelet (with crumbled sausage, bacon, ham & cheddar cheese) stacked on a freshly baked made from scratch biscuit'}
# count: 1350
# {'price': '1.00', 'type': 'ITEM', 'name': ['becconcini', 'di', 'pizza'], 'description': 'Signature pizza balls for di latte, ricotta, soppresata, proscuitto cotto (minimum 4)'}
# count: 1400
# {'type': 'ITEM', 'name': ['pulled', 'pork', 'bbq'], 'description': '4/5 lb. Tubs'}
# count: 1450
# {'price': '5.95', 'type': 'ITEM', 'name': ['pot', 'stickers'], 'description': 'Pan fried dumpling filled with Chicken and green onions'}
# count: 1500
# {'price': '11.50', 'type': 'ITEM', 'name': ['fish', 'burgers'], 'description': 'All fish cut daily in filets. choose from our signature fish (all other fish at market price)'}
# count: 1550
# {'option_groups': [{'text': 'Size', 'type': 'OPTION_CHOOSE', 'options': [{'price': '6.64', 'name': 'Small'}, {'price': '8.41', 'name': 'Large'}]}, {'text': 'Our sauces', 'type': 'OPTION_CHOOSE', 'options': [{'name': 'Salsa'}, {'name': 'Burrito sauce'}, {'name': 'Sour cream'}, {'name': 'Hot sauce'}]}], 'type': 'ITEM', 'name': ['chicken']}
# count: 1600
# {'type': 'ITEM', 'name': ['seafood', 'chowder']}
# count: 1650
# {'option_groups': [{'text': 'Meal', 'type': 'OPTION_CHOOSE', 'options': [{'price': '4.99', 'name': 'Burger'}, {'price': '7.99', 'name': 'Combo'}]}], 'type': 'ITEM', 'name': ['single', 'slab', 'burger']}
# count: 1700
# {'type': 'ITEM', 'name': ['blt'], 'description': 'The\u200e sub that proves great things come in threes. In this case, those three things happen to be crisp bacon, lettuce and juicy tomato. While there is no scientific way of proving it, this B.L.T might be the most perfect sub in existence.'}
# count: 1750
# {'price': '9.00', 'type': 'ITEM', 'name': ['quesadilla'], 'description': 'Grilled chicken\u200f / banana pepper onion / Mexican cheese blend pico de gallo / sriracha sour cream'}
# count: 1800
# {'type': 'ITEM', 'name': ['angus', 'bacon', 'and', 'cheese'], 'description': 'A third-pound* 100% Angus beef patty with its own special seasoning on a premium bakery style bun, hickory smoked bacon, two slices of melty American cheese and topped off with crisp red onions and Crinkle-cut pickles.'}
# count: 1850
# {'price': '8.95', 'option_groups': [{'text': 'Toast', 'type': 'OPTION_CHOOSE', 'options': [{'name': 'White'}, {'name': 'Whole wheat'}, {'name': 'Rye'}, {'name': 'English muffin'}]}], 'type': 'ITEM', 'name': ['fannys', 'crustless', 'quiche'], 'description': 'Our crustless quiche of the day, served with your choice of fresh fruit or scone'}
# count: 1900
# {'price': '6.95', 'type': 'ITEM', 'name': ['bbq', 'nachos'], 'description': 'Chips, pulled\u200f pork, beef or chicken, Lightly breaded deep fried onion pile cheese, jalapeños & pico de gallo'}
# count: 1950
# {'price': '6.00', 'type': 'ITEM', 'name': ['soup', 'of', 'the', 'day']}
# count: 2000
# {'price': '13.99', 'type': 'ITEM', 'name': ['cibo', 'antipasto'], 'description': 'Thinly sliced imported prosciutto di parma, fresh mozzarella and imported cheeses, roasted red peppers, olives, tomatoes and fresh bread'}
# count: 2050
# {'type': 'ITEM', 'name': ['coffee'], 'description': "Tim hortons was founded on the promise of making fresh, delicious coffee every time. And we're as committed today as we were in 1964 to delivering that same special taste of tim hortons premium blend coffee w/ every cup we serve our guests."}
# count: 2100
# {'price': '8.00', 'type': 'ITEM', 'name': ['espresso', 'love'], 'description': 'Patrón XO cafe, espresso & dark chocolate. Like a great coffeehouse experience while hanging out in a bar, which is way more fun.'}
# count: 2150
# {'price': '6.25', 'type': 'ITEM', 'name': ['stuffed', 'banana', 'peppers'], 'description': 'With bread and butter'}
# count: 2200
# {'price': '1.50', 'type': 'ITEM', 'name': ['miso', 'shiru'], 'description': 'soy bean soup'}
# count: 2250
# {'price': '4.99', 'type': 'ITEM', 'name': ['eggs', 'lots', 'of', 'homefries', 'double', 'texas', 'toast']}
# count: 2300
# {'type': 'ITEM', 'name': ['whopper', 'sandwich', 'meal'], 'description': 'Our WHOPPER® Sandwich Meal is a ¼ lb. of savory flame-broiled beef topped with juicy tomatoes, fresh cut lettuce, creamy mayonnaise, crunchy pickles, and sliced white onions on a soft sesame seed bun. Served with a small side of piping hot, thick cut French Fries or golden Onion Rings and a small fountain drink of your choice to make it a meal.'}
# count: 2350
# {'type': 'ITEM', 'name': ['chicken', 'shawarma', 'plate'], 'description': 'Imagine all the savoury ingredients of our chicken shawarma wrap on a plate.'}
# count: 2400
# {'type': 'ITEM', 'name': ['blt'], 'description': 'The sub that proves great things come in threes. In this case, those three things happen to be crisp bacon, lettuce and juicy tomato. While there is no scientific way of proving it, this B.L.T might be the most perfect sub in existence.'}
# count: 2450
# {'type': 'ITEM', 'name': ['whopper', 'sandwich', 'meal'], 'description': 'Our WHOPPER® Sandwich Meal is a ¼ lb. of savory flame-broiled beef topped w/ juicy tomatoes, fresh cut lettuce, creamy mayonnaise, crunchy pickles, & sliced white onions on a soft sesame seed bun. Served w/ a small side of piping hot, thick cut French Fries or golden Onion Rings & a small fountain drink of your choice to make it a meal.'}
# count: 2500
# {'price': '4.50', 'option_groups': [{'text': 'Extra', 'type': 'OPTION_ADD', 'options': [{'price': '+3.00', 'name': 'Tea treats (dates and saffron rock candy )'}]}], 'type': 'ITEM', 'name': ['koma', 'chai', 'chai'], 'description': 'Awtash special Persian blend'}
# count: 2550
# {'price': '4.95', 'type': 'ITEM', 'name': ['crab', 'angel'], 'description': 'Crab meat and cream cheese. Home made, served with orange sauce'}
# count: 2600
# {'price': '15.95', 'type': 'ITEM', 'name': ['eggplant', 'moussaka'], 'description': 'Fried eggplant marinara sauce with ground beef bechamel sauce and mozzarella cheese'}
# count: 2650
# {'type': 'ITEM', 'name': ['orignal', 'recipe'], 'description': "Colonel's secret recipe. This is it - one of the world's most delicious secrets. Colonel sanders created the perfect blend of 11 herbs & spices in corbin kentucky more than 70 years ago, & it's that same secret recipe that's loved all over the world today. The irresistible taste of original recipe starts w/ chicken delivered fresh from trusted suppliers like tyson. Then it's made fresh, seasoned w/ the 11 herbs & spices & hand breaded throughout the day by a certified cook."}
# count: 2700
# {'price': '5.99', 'type': 'ITEM', 'name': ['august', 'deli', 'special'], 'description': 'Sloppy Joe w/ French fries beverage purchase required'}
# count: 2750
# {'type': 'ITEM', 'name': ['egg', 'roll']}
# count: 2800
# {'type': 'ITEM', 'name': ['toast', 'bagels', 'and', 'english', 'muffins'], 'description': 'A variety of white, whole wheat and multigrain toasted breads prepped for you with your choice of spread:'}
# count: 2850
# {'price': '5.50', 'option_groups': [{'text': 'Dressing', 'type': 'OPTION_CHOOSE', 'options': [{'name': 'Balsamic vinaigrette'}, {'name': 'Ranch'}, {'name': 'creamy Italian'}]}, {'text': 'Extra', 'type': 'OPTION_ADD', 'options': [{'price': '+3.00', 'name': 'Chicken'}, {'price': '+4.00', 'name': 'Shrimp'}]}], 'type': 'ITEM', 'name': ['garden', 'salad'], 'description': 'mixed Greens w/ tomato, cucumber, & onions'}
# count: 2900
# {'type': 'ITEM', 'name': ['edamame']}
# count: 2950
# {'price': '5.95', 'type': 'ITEM', 'name': ['zucchini', 'marios', 'original'], 'description': 'Paper thin strips in a light batter garnished with a splash of tangy lemon juice dusted with parmigiana cheese '}
# count: 3000
# {'price': '3.30', 'type': 'ITEM', 'name': ['baked', 'tofu']}
# count: 3050
# {'price': '3.00', 'type': 'ITEM', 'name': ['oysters', 'accompaniments']}
# count: 3100
# {'price': '5.50', 'type': 'ITEM', 'name': ['pieces']}
# count: 3150
# {'type': 'ITEM', 'name': ['red', 'bean', 'dip'], 'description': 'With tortilla chips'}
# count: 3200
# {'price': '8.28', 'option_groups': [{'text': 'Item', 'type': 'OPTION_CHOOSE', 'options': [{'name': 'Biscuit'}, {'name': 'English muffin'}, {'name': 'Toast'}]}], 'type': 'ITEM', 'name': ['copilotilot'], 'description': 'Diced ham & american cheese will surely make a first officer pleased'}
# count: 3250
# {'price': '6.99', 'type': 'ITEM', 'name': ['kung', 'pao', 'chicken']}
# count: 3300
# {'price': '8.99', 'type': 'ITEM', 'name': ['greek', 'plant'], 'description': 'Eggplant rolls filled w/ feta cheese & pesto, served over sweet potato'}
# count: 3350
# {'price': '3.50', 'type': 'ITEM', 'name': ['soup', 'djour'], 'description': 'Soups made fresh daily, ask your server for details.'}
# count: 3400
# {'price': '4.95', 'type': 'ITEM', 'name': ['dubonnet']}

# %% [markdown]
# # match menu and food entity in review, label them using 'BILOU'

# %%
def is_match(start_idx, review_tokens, food_tokens):
    matched_count = len(food_tokens)
    if start_idx + len(food_tokens) > len(review_tokens):
        return False
    if review_tokens[start_idx] != food_tokens[0].lower():
        return False
    for idx in range(len(food_tokens)):
        if review_tokens[start_idx + idx].lower() != food_tokens[idx].lower():
            matched_count = matched_count - 1
            if matched_count/len(food_tokens) < 2/3:
                return False
    return True

# %%
REVIEW_FILE_NAME = 'tokenized_reviews.pickle'
BUZ_FILE_NAME = 'buzs_tokenized.pickle'
REVIEW_LABEL_FILE_NAME = 'labeled_reviews.txt'
buz_reviews = pickle.load(open(REVIEW_FILE_NAME, 'rb'))
buzs = pickle.load(open(BUZ_FILE_NAME, 'rb'))

# %%
review_count = 0
matched_sent_count = 0
tokenized_reviews = []
with open(REVIEW_LABEL_FILE_NAME, 'w') as f:
    for buz_id, reviews in buz_reviews.items():
        menu = buzs[buz_id]['menu']
        for review in reviews:
            review_count += 1
            if review_count % 1000 == 0:
                print('review count:', review_count)
                print('sentence count:', matched_sent_count)
            for tokens in review['text']: 
                labeled_tokens = []
                if len(tokens) == 0:
                    continue
                idx = 0
                matched_food_count = 0
                total_food_length=0
                while idx < len(tokens):
                    # check match
                    match = False
                    for food in menu:
                        food_tokens = food['name']
                        if len(food_tokens) < 1:
                            continue
                        match = is_match(idx, tokens, food_tokens)
                        if match:
                            matched_food_count += 1
                            food_len = len(food_tokens)
                            matched_len = (food_len-1, food_len)[tokens[idx+food_len-1]==food_tokens[-1]]
                            if food_len == 1:
                                labeled_tokens.append((tokens[idx], 'U'))
                            else:
                                labeled_tokens.append((tokens[idx], 'B'))
                                for i in range(1, matched_len - 1):
                                    labeled_tokens.append((tokens[idx + i], 'I'))
                                labeled_tokens.append((tokens[idx + matched_len - 1], 'L'))
                            idx += matched_len
                            total_food_length += matched_len
                            break
                    if not match:
                        labeled_tokens.append((tokens[idx], 'O'))
                        idx += 1
                
                if total_food_length/len(tokens)>=0.4 or matched_food_count >= 3:
                    matched_sent_count += 1
                    temp=[]
                    for token in labeled_tokens:
                        temp.append(token[0])
                        f.write(token[0]+'\t'+token[1]+'\n')
                    f.write('\n')
                    tokenized_reviews.append(temp)
    
print('final review count:', review_count)
print('final matched sentence count:', matched_sent_count)
# Out:
# final review count: 301773
# final matched sentence count: 21402

# %% [markdown]
# # Take the labeled_review json file as input, generate txt file (deprecated)

# %%
REVIEW_LABEL_TXT_NAME = 'labeled_reviews.txt'
review_count = 0

with open(REVIEW_LABEL_FILE_NAME, 'r') as json_data, open(REVIEW_LABEL_TXT_NAME, 'w') as txt_data:
    for line in json_data:
        review_count += 1
        if review_count % 1000 == 0:
            print('processed reviews: ', review_count)
        review = json.loads(line)
        tokens = review['text']
        for token in tokens:
            txt_data.write(token[0]+'\t'+token[1]+'\n')
        txt_data.write('\n')
    print('final count ', review_count)
# Out:
# final count  501
